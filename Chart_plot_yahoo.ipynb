# %% [markdown]
# <a href="https://colab.research.google.com/github/FabiPYT/pythonProject/blob/master/Chart_plot_yahoo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
dataframe = pd.read_csv("BTC-USD.csv")

#nur Closing Stock Value anzeigen
extr_dataframe = dataframe[["Date","Adj Close"]]


#nach Datum sortieren
extr_dataframe_sorted = extr_dataframe.sort_values(["Date"], ascending=True)
extr_dataframe_sorted_indexed = extr_dataframe_sorted.set_index("Date")


#Graph einführen
extr_dataframe_sorted_indexed.plot(figsize=(30,16))

#Schwarzer Hintergrund
#plt.style.use("white_background")
#-> funktioniert nicht

#Überschrift
plt.title("BTC-USD - Halvings", fontsize=20)

#y-Achse logarithmisch
#plt.yscale('log',base =2)
#-> repräsentierende Darstellung ohne Basis finden

#Achsenbeschriftung
plt.xlabel("Date",fontsize=12)
plt.ylabel("USD - logarithmic",fontsize=12)

#Gitternetz einfügen
#plt.grid()

#Skalierung absolut y-Achse
plt.ylim(0, 25000)
plt.xlim(0, 2500)

#Skalierung Abstufung y-Achse
#plt.yticks(np.arange(0, 25000, 5)) # -> durch logarithmus funktioniert Skalierung nichtmehr
#plt.xticks(np.arange(0, 2500, 10))
#plt.yticks(np.arange(0, 100000, 10))

#dateformat in monat/Jahr (mit DateFormatter), Eingabeformate (https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior
#date_format = DateFormatter("%b-%Y")
#loc = MonthLocator(bymonth=Aug, bymonthday=1, interval=1, tz=none)

#Skalierung x-Achse (in Datetime umwandeln)


#Vertikale  Linie an der Stelle 'x_pos' für Halvings
plt.axvline(x=664, color="w", linestyle= "--") #von 2014-09-17 bis 2. Halving am 11. Juli 2016 entspricht x=664 Tage 
plt.axvline(x=2071, color="w", linestyle= "--") #von 2014-09-17 bis 3. Halving am 20. Mai 2020 entspricht x=2071 Tage

#plt.vlines(x = 1000, color = "a", ymin = 0, ymax = 25000)
#-> position in datetime bekommen

#Bereiche markieren
plt.axvspan(664,1189,ymin= 0.025, ymax= 0.78, color="g" ,alpha=0.3)
#plt.axvspan(set_ylim= (600, 19800) )

plt.yscale("")
plt.plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-27ec19606619> in <module>()
#      61 #plt.axvspan(set_ylim= (600, 19800) )
#      62
# ---> 63 plt.yscale("")
#      64 plt.plot()
#      65
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in yscale(value, **kwargs)
#    3056 @docstring.copy(Axes.set_yscale)
#    3057 def yscale(value, **kwargs):
# -> 3058     return gca().set_yscale(value, **kwargs)
#    3059
#    3060
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in set_yscale(self, value, **kwargs)
#    3672         g = self.get_shared_y_axes()
#    3673         for ax in g.get_siblings(self):
# -> 3674             ax.yaxis._set_scale(value, **kwargs)
#    3675             ax._update_transScale()
#    3676             ax.stale = True
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axis.py in _set_scale(self, value, **kwargs)
#     824
#     825     def _set_scale(self, value, **kwargs):
# --> 826         self._scale = mscale.scale_factory(value, self, **kwargs)
#     827         self._scale.set_default_locators_and_formatters(self)
#     828
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/scale.py in scale_factory(scale, axis, **kwargs)
#     726     """
#     727     scale = scale.lower()
# --> 728     cbook._check_in_list(_scale_mapping, scale=scale)
#     729     return _scale_mapping[scale](axis, **kwargs)
#     730
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/cbook/__init__.py in _check_in_list(_values, **kwargs)
#    2143             raise ValueError(
#    2144                 "{!r} is not a valid value for {}; supported values are {}"
# -> 2145                 .format(v, k, ', '.join(map(repr, values))))
#    2146
#    2147
#
# ValueError: '' is not a valid value for scale; supported values are 'linear', 'log', 'symlog', 'logit', 'function', 'functionlog'
